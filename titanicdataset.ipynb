# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
import pandas as pd

# %%
train_df = pd.read_csv('/kaggle/input/titanic/train.csv')
test_df = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
combine = [train_df,test_df]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.columns.values.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
percent_missing = train_df['Age'].isnull().sum() * 100 / len(train_df)
print("Percent of missing 'Age' records is %.2f" %percent_missing)
# Out:
# Percent of missing 'Age' records is 19.87

# %%
percent_missing_embarked = train_df['Embarked'].isnull().sum() * 100 / len(train_df)
print("Percent of missing 'Embarked' records is %.2f" %percent_missing_embarked)
# Out:
# Percent of missing 'Embarked' records is 0.22

# %%
# import numpy as np
# from sklearn.impute import SimpleImputer
# imp = SimpleImputer(missing_values = np.nan,strategy = "mean")
# trans = imp.fit_transform(train_df['Age'].to_numpy().reshape(-1, 1))
# trans.reshape(1,-1)

# %%
import math

# %%
age_mean = train_df['Age'].mean()
age_mean
# Out:
# 29.69911764705882

# %%
num_rows = train_df['Age'].shape[0]
num_rows
# Out:
# 891

# %%
for i in range(num_rows):
    if math.isnan(train_df['Age'][i]):
        train_df['Age'][i] = age_mean
train_df
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# ...

# %%
train_df["Embarked"].fillna(train_df["Embarked"].value_counts().idxmax(),inplace=True)

# %%
train_df["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
train_df.drop("Cabin", axis=1, inplace=True)
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
train_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train_df = pd.get_dummies(train_df,columns=['Sex','Pclass','Embarked'])
train_df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
train_df.drop("Sex_female", axis=1, inplace=True)
train_df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
test_df["Embarked"].fillna(test_df["Embarked"].value_counts().idxmax(),inplace=True)
test_df["Age"].fillna(test_df["Age"].mean(),inplace=True)
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
test_df['Age']
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
test_df['Age'].mean()
# Out:
# 30.272590361445783

# %%
test_df.drop("Cabin", axis=1, inplace=True)
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
test_df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
test_df = pd.get_dummies(test_df,columns=["Sex","Embarked","Pclass"])
test_df.drop("Sex_female",axis = 1,inplace = True)
test_df
# Out:
#      PassengerId                                          Name       Age  \
# 0            892                              Kelly, Mr. James  34.50000
# 1            893              Wilkes, Mrs. James (Ellen Needs)  47.00000
# 2            894                     Myles, Mr. Thomas Francis  62.00000
# 3            895                              Wirz, Mr. Albert  27.00000
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.00000
# ..           ...                                           ...       ...
# 413         1305                            Spector, Mr. Woolf  30.27259
# 414         1306                  Oliva y Ocana, Dona. Fermina  39.00000
# 415         1307                  Saether, Mr. Simon Sivertsen  38.50000
# 416         1308                           Ware, Mr. Frederick  30.27259
# 417         1309                      Peter, Master. Michael J  30.27259
#
#      SibSp  Parch              Ticket      Fare  Sex_male  Embarked_C  \
# ...

# %%
train_df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare  Sex_male  Pclass_1  \
# 0  22.0      1      0         A/5 21171   7.2500         1         0
# 1  38.0      1      0          PC 17599  71.2833         0         1
# 2  26.0      0      0  STON/O2. 3101282   7.9250         0         0
# 3  35.0      1      0            113803  53.1000         0         1
# 4  35.0      0      0            373450   8.0500         1         0
#
#    Pclass_2  Pclass_3  Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
train_df.drop("Name",axis = 1,inplace = True)
train_df.drop("PassengerId",axis = 1,inplace = True)
train_df.drop("Ticket",axis = 1,inplace = True)
train_df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  Sex_male  Pclass_1  Pclass_2  \
# 0         0  22.0      1      0   7.2500         1         0         0
# 1         1  38.0      1      0  71.2833         0         1         0
# 2         1  26.0      0      0   7.9250         0         0         0
# 3         1  35.0      1      0  53.1000         0         1         0
# 4         0  35.0      0      0   8.0500         1         0         0
#
#    Pclass_3  Embarked_C  Embarked_Q  Embarked_S
# 0         1           0           0           1
# 1         0           1           0           0
# 2         1           0           0           1
# 3         0           0           0           1
# 4         1           0           0           1

# %%
train_df['TravelAlone']=np.where((train_df["SibSp"]+train_df["Parch"])>0, 0, 1) #combining with condition
train_df
# Out:
#      Survived        Age  SibSp  Parch     Fare  Sex_male  Pclass_1  Pclass_2  \
# 0           0  22.000000      1      0   7.2500         1         0         0
# 1           1  38.000000      1      0  71.2833         0         1         0
# 2           1  26.000000      0      0   7.9250         0         0         0
# 3           1  35.000000      1      0  53.1000         0         1         0
# 4           0  35.000000      0      0   8.0500         1         0         0
# ..        ...        ...    ...    ...      ...       ...       ...       ...
# 886         0  27.000000      0      0  13.0000         1         0         1
# 887         1  19.000000      0      0  30.0000         0         1         0
# 888         0  29.699118      1      2  23.4500         0         0         0
# 889         1  26.000000      0      0  30.0000         1         1         0
# 890         0  32.000000      0      0   7.7500         1         0         0
#
# ...

# %%
train_df.drop("SibSp",axis = 1,inplace = True)
train_df.drop("Parch",axis = 1,inplace = True)
train_df
# Out:
#      Survived        Age     Fare  Sex_male  Pclass_1  Pclass_2  Pclass_3  \
# 0           0  22.000000   7.2500         1         0         0         1
# 1           1  38.000000  71.2833         0         1         0         0
# 2           1  26.000000   7.9250         0         0         0         1
# 3           1  35.000000  53.1000         0         1         0         0
# 4           0  35.000000   8.0500         1         0         0         1
# ..        ...        ...      ...       ...       ...       ...       ...
# 886         0  27.000000  13.0000         1         0         1         0
# 887         1  19.000000  30.0000         0         1         0         0
# 888         0  29.699118  23.4500         0         0         0         1
# 889         1  26.000000  30.0000         1         1         0         0
# 890         0  32.000000   7.7500         1         0         0         1
#
#      Embarked_C  Embarked_Q  Embarked_S  TravelAlone
# ...

# %%
test_df.drop("Name",axis = 1,inplace = True)
test_df.drop("PassengerId",axis = 1,inplace = True)
test_df.drop("Ticket",axis = 1,inplace = True)
test_df.head()
# Out:
#     Age  SibSp  Parch     Fare  Sex_male  Embarked_C  Embarked_Q  Embarked_S  \
# 0  34.5      0      0   7.8292         1           0           1           0
# 1  47.0      1      0   7.0000         0           0           0           1
# 2  62.0      0      0   9.6875         1           0           1           0
# 3  27.0      0      0   8.6625         1           0           0           1
# 4  22.0      1      1  12.2875         0           0           0           1
#
#    Pclass_1  Pclass_2  Pclass_3
# 0         0         0         1
# 1         0         0         1
# 2         0         1         0
# 3         0         0         1
# 4         0         0         1

# %%
test_df['TravelAlone']=np.where((test_df["SibSp"]+test_df["Parch"])>0, 0, 1) #combining with condition
test_df.head()
# Out:
#     Age  SibSp  Parch     Fare  Sex_male  Embarked_C  Embarked_Q  Embarked_S  \
# 0  34.5      0      0   7.8292         1           0           1           0
# 1  47.0      1      0   7.0000         0           0           0           1
# 2  62.0      0      0   9.6875         1           0           1           0
# 3  27.0      0      0   8.6625         1           0           0           1
# 4  22.0      1      1  12.2875         0           0           0           1
#
#    Pclass_1  Pclass_2  Pclass_3  TravelAlone
# 0         0         0         1            1
# 1         0         0         1            0
# 2         0         1         0            1
# 3         0         0         1            1
# 4         0         0         1            0

# %%
test_df.drop("SibSp",axis = 1,inplace = True)
test_df.drop("Parch",axis = 1,inplace = True)
test_df
# Out:
#           Age      Fare  Sex_male  Embarked_C  Embarked_Q  Embarked_S  \
# 0    34.50000    7.8292         1           0           1           0
# 1    47.00000    7.0000         0           0           0           1
# 2    62.00000    9.6875         1           0           1           0
# 3    27.00000    8.6625         1           0           0           1
# 4    22.00000   12.2875         0           0           0           1
# ..        ...       ...       ...         ...         ...         ...
# 413  30.27259    8.0500         1           0           0           1
# 414  39.00000  108.9000         0           1           0           0
# 415  38.50000    7.2500         1           0           0           1
# 416  30.27259    8.0500         1           0           0           1
# 417  30.27259   22.3583         1           1           0           0
#
#      Pclass_1  Pclass_2  Pclass_3  TravelAlone
# 0           0         0         1            1
# ...

# %%
test_df.isnull().sum()
# Out:
# Age            0
# Fare           1
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# Pclass_1       0
# Pclass_2       0
# Pclass_3       0
# TravelAlone    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test  = train_test_split(train_df.drop('Survived',axis=1), train_df['Survived'], test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

# %%
log_model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
predict = log_model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       157
#            1       0.80      0.71      0.75       111
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.79      0.80       268
# weighted avg       0.81      0.81      0.80       268

# %%
from sklearn import metrics
print("Accuracy: ",metrics.accuracy_score(y_test,predict))
# Out:
# Accuracy:  0.8059701492537313
